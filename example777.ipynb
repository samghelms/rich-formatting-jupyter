# %%
from pandas_ext.UpdatedDataFrame2 import UpdatedDataFrame as DataFrame
import pandas as pd
from IPython.core.display import display, HTML

# %%
script = \
"""
<script>
requirejs.config({
    paths: { 
       'katex': ['//cdnjs.cloudflare.com/ajax/libs/KaTeX/0.9.0-beta1/katex.min'], 
                                              // strip .js ^, require adds it back
    },
});

require(['katex'], function(katex) {
     console.log("Loaded :)");
     console.log(katex)
     window.katex = katex
     return {};
});
</script>
"""

# %%
display(HTML(script))
# Out:
# <script>
# requirejs.config({
#     paths: {
#        'katex': ['//cdnjs.cloudflare.com/ajax/libs/KaTeX/0.9.0-beta1/katex.min'],
#                                               // strip .js ^, require adds it back
#     },
# });
#
# require(['katex'], function(katex) {
#      console.log("Loaded :)");
#      console.log(katex)
#      window.katex = katex
#      return {};
# });
# </script>

# %%
display(HTML('<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/KaTeX/0.9.0-beta1/katex.min.css" integrity="sha384-VEnyslhHLHiYPca9KFkBB3CMeslnM9CzwjxsEbZTeA21JBm7tdLwKoZmCt3cZTYD" crossorigin="anonymous">'))
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/KaTeX/0.9.0-beta1/katex.min.css" integrity="sha384-VEnyslhHLHiYPca9KFkBB3CMeslnM9CzwjxsEbZTeA21JBm7tdLwKoZmCt3cZTYD" crossorigin="anonymous">

# %%
from IPython.display import (display_javascript,
                                         display_html)
from uuid import uuid1
class katex:
    def __init__(self, s):
        self._s = s
        self.dep = "katex"
        self._ids = []
        self._whenavailable_func = ("function whenAvailable(name, callback) {\n"
                                "\tvar interval = 10; // ms\n"
                                "\twindow.setTimeout(function() {\n"
                                "\tif (window[name]) {\n"
                                "\t\tcallback();\n"
                                "\t} else {\n"
                                "\t\twindow.setTimeout(arguments.callee, interval);\n"
                                "\t}\n"
                                "}, interval);\n"
                                "}\n")
        _parent = 'var parent = document.getElementById(id);'
        _body = lambda math: "\n".join(["var newChild = document.createElement('span');",
                                        "window.katex.render('{math}', newChild);".format(math=math),
                                        "parent.appendChild(newChild);"])
        self._fn = lambda math: "function render_katex(id) { \n\t"+_parent+"\n\t"+_body(math)+"\n}"
        self._exec = lambda uid: 'whenAvailable("katex", function(){render_katex("'+uid+'")});'
        
    def _repr_html_(self):
        unique_id = str(uuid1())
        anchor = '<div id="{unique_id}"/>'.format(unique_id=unique_id)
        self._ids.append(unique_id)
        return anchor

    def _repr_javascript_(self):
        js = []
        while len(self._ids) > 0:
            i = self._ids.pop(0)
            funcs = "\n".join([self._whenavailable_func, self._fn(self._s), self._exec(i)])
            js.append(funcs)
        return "\n".join(js)
    
    def _ipython_display_(self):
        display_html(self._repr_html_(), raw=True)
        display_javascript(self._repr_javascript_(), raw=True)

# %%
k = katex(r"\\int x = \\frac{x}{y} = \\frac{\\lambda y + 100}{\\int e = mc^2}")
k
# Out:
# <div id="708019d2-11f0-11e8-be73-600308a8611a"/>

# %%
k
# Out:
# <div id="71de6e28-11f0-11e8-a329-600308a8611a"/>

# %%
df_5 = DataFrame([k, k])
df_1 = DataFrame([df_5, df_5])

DataFrame([df_1, df_1])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div id="72495c58-11f0-11e8-8f06-600308a8611a"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div id="72495d9e-11f0-11e8-b988-600308a8611a"/></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div id="72499180-11f0-11e8-a59b-600308a8611a"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div id="724992ac-11f0-11e8-a291-600308a8611a"/></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div id="7249e554-11f0-11e8-b028-600308a8611a"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div id="7249e676-11f0-11e8-ad5a-600308a8611a"/></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div id="724a1858-11f0-11e8-9e07-600308a8611a"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div id="724a19a2-11f0-11e8-b88b-600308a8611a"/></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
DataFrame([df_1, df_1])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div id="728b032c-11f0-11e8-97e7-600308a8611a"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div id="728b04a8-11f0-11e8-bcfd-600308a8611a"/></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div id="728b2db6-11f0-11e8-b91b-600308a8611a"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div id="728b2eec-11f0-11e8-829a-600308a8611a"/></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div id="728b76e2-11f0-11e8-bfc2-600308a8611a"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div id="728b781e-11f0-11e8-9eeb-600308a8611a"/></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="None">
#   <thead>
#   <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#   </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td class="row-0 col-0"><div id="728b9a9e-11f0-11e8-946b-600308a8611a"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td class="row-1 col-0"><div id="728b9bca-11f0-11e8-ae0e-600308a8611a"/></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#   </tbody>
# </table>
# </div></td>
#     </tr>
#   </tbody>
# </table>
# </div>
